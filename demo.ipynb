# %%
from Modelo_Estandar.particulas import Particula
from Modelo_Estandar.analisis import crear_dataframe, graficar_masa, graficar_distribucion_tipos
from Modelo_Estandar.gui import ModeloEstandarApp
from PyQt5.QtWidgets import QApplication
import sys

#Crear un conjunto de partículas de ejemplo
particles = {
    'electron': Particula("Electrón", "lepton", -1, 0.51099895000),
    'muon': Particula("Muón", "lepton", -1, 105.6583755),
    'tau': Particula("Tau", "lepton", -1, 1776.93),
    'photon': Particula("Fotón", "boson", 0, 0),
    'higgs_boson': Particula("Bosón de Higgs", "boson", 0, 125090)
}

#Crear un DataFrame a partir de las partículas
df = crear_dataframe(particles)

#Mostrar el DataFrame
print("Tabla de partículas:")
print(df)

#Graficar la masa de las partículas
print("\nGraficando la masa de las partículas:")
graficar_masa(df)

#Graficar la distribución de los tipos de partículas
print("\nGraficando la distribución de tipos de partículas:")
graficar_distribucion_tipos(df)

#Mostrar información detallada de una partícula
print("\nInformación detallada de una partícula específica:")
print(particles['electron'].mostrar_info())

#Ejecutar pruebas unitarias con unittest
print("\nEjecutando pruebas unitarias con unittest:")
# !python -m unittest discover -s tests

#Ejecutar pruebas unitarias con pytest
print("\nEjecutando pruebas unitarias con pytest:")
# !pytest tests/
# Out:
# Tabla de partículas:
#            Nombre    Tipo  Carga (e)  Masa (MeV/c^2) Carga de Color Sabor
# 0        Electrón  lepton         -1        0.510999           None  None
# 1            Muón  lepton         -1      105.658376           None  None
# 2             Tau  lepton         -1     1776.930000           None  None
# 3           Fotón   boson          0        0.000000           None  None
# 4  Bosón de Higgs   boson          0   125090.000000           None  None
#
# Graficando la masa de las partículas:
# Graficando la distribución de tipos de partículas:
# Información detallada de una partícula específica:
# Partícula: Electrón
# Tipo: lepton
# Carga: -1 e
# Masa: 0.51099895 MeV/c^2
#
#
# Ejecutando pruebas unitarias con unittest:
# Traceback (most recent call last):
#   File "/Users/nico/anaconda3/envs/nuevo_entorno/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
# ...
